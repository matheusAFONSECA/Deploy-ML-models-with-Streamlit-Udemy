# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/used_car_canada_clean.csv')
display(df)
# Out:
#            price    miles    year           make          model body_type  \
# 0       179999.0   9966.0  2017.0          acura            NSX     coupe
# 1       179995.0   5988.0  2017.0          acura            NSX     coupe
# 2       168528.0  24242.0  2017.0          acura            NSX     coupe
# 3       220000.0   6637.0  2020.0          acura            NSX     coupe
# 4       220000.0   6637.0  2020.0          acura            NSX     coupe
# ...          ...      ...     ...            ...            ...       ...
# 269488   43900.0  68665.0  2018.0  mercedes_benz      GLC-Class       suv
# 269489   47995.0  22108.0  2019.0  mercedes_benz      GLC-Class       suv
# 269490   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class       suv
# 269491   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class       suv
# 269492  113530.0   7595.0  2020.0        porsche  Cayenne Coupe       suv
#
#        vehicle_type drivetrain transmission fuel_type  engine_size  \
# 0               Car        4WD    Automatic     hyrid          3.5
# 1               Car        4WD    Automatic     hyrid          3.5
# 2               Car        4WD    Automatic     hyrid          3.5
# 3               Car        4WD    Automatic     hyrid          3.5
# 4               Car        4WD    Automatic     hyrid          3.5
# ...             ...        ...          ...       ...          ...
# 269488        Truck        4WD    Automatic     hyrid          2.0
# 269489        Truck        4WD    Automatic     hyrid          2.0
# 269490        Truck        4WD    Automatic     hyrid          2.0
# 269491        Truck        4WD    Automatic     hyrid          2.0
# 269492        Truck        4WD    Automatic     hyrid          3.0
#
#        engine_block state
# 0                 V    NB
# 1                 V    QC
# 2                 V    BC
# 3                 V    ON
# 4                 V    ON
# ...             ...   ...
# 269488            I    QC
# 269489            I    QC
# 269490            I    QC
# 269491            I    QC
# 269492            V    ON
#
# [269493 rows x 13 columns]

# %%
cols_to_drop = ['body_type', 'vehicle_type', 'drivetrain', 'transmission', 'fuel_type', 'engine_block']
df = df.drop(cols_to_drop, axis=1)

# %%
display(df)
# Out:
#            price    miles    year           make          model  engine_size  \
# 0       179999.0   9966.0  2017.0          acura            NSX          3.5
# 1       179995.0   5988.0  2017.0          acura            NSX          3.5
# 2       168528.0  24242.0  2017.0          acura            NSX          3.5
# 3       220000.0   6637.0  2020.0          acura            NSX          3.5
# 4       220000.0   6637.0  2020.0          acura            NSX          3.5
# ...          ...      ...     ...            ...            ...          ...
# 269488   43900.0  68665.0  2018.0  mercedes_benz      GLC-Class          2.0
# 269489   47995.0  22108.0  2019.0  mercedes_benz      GLC-Class          2.0
# 269490   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class          2.0
# 269491   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class          2.0
# 269492  113530.0   7595.0  2020.0        porsche  Cayenne Coupe          3.0
#
#        state
# 0         NB
# 1         QC
# 2         BC
# 3         ON
# 4         ON
# ...      ...
# 269488    QC
# 269489    QC
# 269490    QC
# 269491    QC
# 269492    ON
#
# [269493 rows x 7 columns]

# %%
df_toyota_honda = df.loc[(df['make'] == 'honda') | (df['make'] == 'toyota')]

# %%
df_toyota_honda.to_csv('../data/honda_toyota_ca.csv', index=False, header=True)

# %% [markdown]
# ## Model

# %%
df = pd.read_csv('../data/honda_toyota_ca.csv')
display(df)
# Out:
#          price     miles    year    make       model  engine_size state
# 0       4980.0   86132.0  2001.0  toyota       Prius          1.5    BC
# 1       4488.0  310119.0  2006.0  toyota  Highlander          3.3    ON
# 2       7650.0  135000.0  2006.0  toyota  Highlander          3.3    ON
# 3       8900.0  130160.0  2010.0   honda       Civic          1.8    BC
# 4      12995.0   81000.0  2015.0   honda       Civic          1.8    ON
# ...        ...       ...     ...     ...         ...          ...   ...
# 39235  32995.0  100785.0  2018.0  toyota        RAV4          2.5    BC
# 39236  27995.0  100850.0  2018.0  toyota        RAV4          2.5    BC
# 39237  26785.0  132012.0  2018.0  toyota        RAV4          2.5    AB
# 39238  23358.0  142999.0  2018.0  toyota        RAV4          2.5    ON
# 39239   4490.0  255000.0  2007.0  toyota       Camry          2.4    ON
#
# [39240 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=df[['make', 'model']], test_size=0.2, shuffle=True, random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor

cat_index = [2,3,5]

cat_features_transformer = Pipeline(
    steps=[
        ("encoder", OneHotEncoder()),
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", cat_features_transformer, cat_index)
    ]
)


model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("regressor", GradientBoostingRegressor(random_state=42))
    ]
)

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder())]),
#                                                   [2, 3, 5])])),
#                 ('regressor', GradientBoostingRegressor(random_state=42))])

# %%
model.score(X_test, y_test)
# Out:
# 0.4865534075230413

# %%
from joblib import dump

dump(model, '../model/model.joblib')
# Out:
# ['../model/model.joblib']
