# %% [markdown]
# Data source: https://www.kaggle.com/datasets/rupeshraundal/marketcheck-automotive-data-us-canada?select=ca-dealers-used.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/ca-dealers-used.csv')
display(df)
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_8756\3560608208.py:1: DtypeWarning: Columns (13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/ca-dealers-used.csv')
#                    id                vin     price    miles   stock_no  \
# 0       b39ea795-eca9  19UNC1B01HY800062  179999.0   9966.0    V-P4139
# 1       026cb5b1-6e3e  19UNC1B02HY800023  179995.0   5988.0  PPAP70374
# 2       5cd5d5b2-5cc2  19UNC1B02HY800071  168528.0  24242.0     B21085
# 3       b32473ed-5922  19UNC1B02LY800001  220000.0   6637.0     AP5333
# 4       ac40c9fc-0676  19UNC1B02LY800001  220000.0   6637.0     AP5333
# ...               ...                ...       ...      ...        ...
# 393598  f71c5738-33d8  WDC0G5EB8KF614677   47995.0  22108.0      M0684
# 393599  873d76f0-18d2  WDC0G5EB9JF465808   42995.0  55316.0     D13339
# 393600  7ead9dba-6cdd  WDC0G5EB9JF465808   42995.0  55316.0     D13339
# 393601  efa897c2-a52f  WP1BE2AY4LDA55072  115995.0      NaN        NaN
# 393602  479607ed-62af  WP1BE2AY8LDA55284  113530.0   7595.0     P16107
#
#           year           make          model      trim body_type  ...  \
# 0       2017.0          Acura            NSX      Base     Coupe  ...
# 1       2017.0          Acura            NSX      Base     Coupe  ...
# 2       2017.0          Acura            NSX      Base     Coupe  ...
# 3       2020.0          Acura            NSX      Base     Coupe  ...
# 4       2020.0          Acura            NSX      Base     Coupe  ...
# ...        ...            ...            ...       ...       ...  ...
# 393598  2019.0  Mercedes-Benz      GLC-Class   GLC350e       SUV  ...
# 393599  2018.0  Mercedes-Benz      GLC-Class   GLC350e       SUV  ...
# 393600  2018.0  Mercedes-Benz      GLC-Class   GLC350e       SUV  ...
# 393601  2020.0        Porsche  Cayenne Coupe  E-Hybrid       SUV  ...
# 393602  2020.0        Porsche  Cayenne Coupe  E-Hybrid       SUV  ...
#
#        drivetrain transmission                    fuel_type engine_size  \
# 0             4WD    Automatic  Electric / Premium Unleaded         3.5
# 1             4WD    Automatic  Electric / Premium Unleaded         3.5
# 2             4WD    Automatic  Electric / Premium Unleaded         3.5
# 3             4WD    Automatic  Electric / Premium Unleaded         3.5
# 4             4WD    Automatic  Electric / Premium Unleaded         3.5
# ...           ...          ...                          ...         ...
# 393598        4WD    Automatic          Electric / Unleaded         2.0
# 393599        4WD    Automatic          Electric / Unleaded         2.0
# 393600        4WD    Automatic          Electric / Unleaded         2.0
# 393601        4WD    Automatic          Electric / Unleaded         3.0
# 393602        4WD    Automatic          Electric / Unleaded         3.0
#
#         engine_block                                   seller_name  \
# 0                  V                              edmundston honda
# 1                  V                         garage daniel lessard
# 2                  V                                lougheed acura
# 3                  V                               drive autogroup
# 4                  V                               acura pickering
# ...              ...                                           ...
# 393598             I                          mercedes-benz granby
# 393599             I  groupe park avenue - regroupement automobile
# 393600             I          le mga centre park avenue la prairie
# 393601             V                       porsche centre winnipeg
# 393602             V                             h.j. pfaff motors
#
#                                 street                 city state      zip
# 0                     475 Rue Victoria           Edmundston    NB  E3V 2K7
# 1       2795 Route-du-prsident-kennedy  Notre-dame-des-pins    QC  G0M 1K0
# 2                1388 Lougheed Highway            Coquitlam    BC  V3K 6S4
# 3               1305 Parkway Suite 600            Pickering    ON  L1V 3P2
# 4                    575 Kingston Road            Pickering    ON  L1V 3N7
# ...                                ...                  ...   ...      ...
# 393598             1225 Rue Principale               Granby    QC  J2J 0M3
# 393599       8840 Boulevard Taschereau             Brossard    QC  J4X 1C2
# 393600      150-b Boulevard Taschereau           La Prairie    QC  J5R 1S8
# 393601             660 Pembina Highway             Winnipeg    MB  R3M 2M5
# 393602                33 Auto Park Cir           Woodbridge    ON  L4L 8R1
#
# [393603 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# id                  0
# vin                 0
# price           35117
# miles           27013
# stock_no        27693
# year               17
# make                0
# model            4794
# trim            38779
# body_type       34025
# vehicle_type    38238
# drivetrain      38995
# transmission    35681
# fuel_type       70813
# engine_size     72653
# engine_block    73164
# seller_name      2232
# street           7929
# city             7774
# state            7836
# zip              7769
# dtype: int64

# %%
df.shape
# Out:
# (393603, 21)

# %%
cols_to_drop = ['id', 'vin', 'trim', 'stock_no', 'street', 'zip', 'seller_name', 'city']
df = df.drop(cols_to_drop, axis=1)

df.shape
# Out:
# (393603, 13)

# %%
df.dtypes
# Out:
# price           float64
# miles           float64
# year            float64
# make             object
# model            object
# body_type        object
# vehicle_type     object
# drivetrain       object
# transmission     object
# fuel_type        object
# engine_size     float64
# engine_block     object
# state            object
# dtype: object

# %%
df = df.dropna(axis=0)

# %%
df[['make', 'model', 'body_type', 'vehicle_type', 'drivetrain', 'transmission', 'fuel_type', 'engine_block', 'state']] = df[['make', 'model', 'body_type', 'vehicle_type', 'drivetrain', 'transmission', 'fuel_type', 'engine_block', 'state']].astype("string")

df.dtypes
# Out:
# price                  float64
# miles                  float64
# year                   float64
# make            string[python]
# model           string[python]
# body_type       string[python]
# vehicle_type    string[python]
# drivetrain      string[python]
# transmission    string[python]
# fuel_type       string[python]
# engine_size            float64
# engine_block    string[python]
# state           string[python]
# dtype: object

# %%
df.shape
# Out:
# (269552, 13)

# %%
df.isna().sum()
# Out:
# price           0
# miles           0
# year            0
# make            0
# model           0
# body_type       0
# vehicle_type    0
# drivetrain      0
# transmission    0
# fuel_type       0
# engine_size     0
# engine_block    0
# state           0
# dtype: int64

# %%
display(df)
# Out:
#            price    miles    year           make          model body_type  \
# 0       179999.0   9966.0  2017.0          Acura            NSX     Coupe
# 1       179995.0   5988.0  2017.0          Acura            NSX     Coupe
# 2       168528.0  24242.0  2017.0          Acura            NSX     Coupe
# 3       220000.0   6637.0  2020.0          Acura            NSX     Coupe
# 4       220000.0   6637.0  2020.0          Acura            NSX     Coupe
# ...          ...      ...     ...            ...            ...       ...
# 393597   43900.0  68665.0  2018.0  Mercedes-Benz      GLC-Class       SUV
# 393598   47995.0  22108.0  2019.0  Mercedes-Benz      GLC-Class       SUV
# 393599   42995.0  55316.0  2018.0  Mercedes-Benz      GLC-Class       SUV
# 393600   42995.0  55316.0  2018.0  Mercedes-Benz      GLC-Class       SUV
# 393602  113530.0   7595.0  2020.0        Porsche  Cayenne Coupe       SUV
#
#        vehicle_type drivetrain transmission                    fuel_type  \
# 0               Car        4WD    Automatic  Electric / Premium Unleaded
# 1               Car        4WD    Automatic  Electric / Premium Unleaded
# 2               Car        4WD    Automatic  Electric / Premium Unleaded
# 3               Car        4WD    Automatic  Electric / Premium Unleaded
# 4               Car        4WD    Automatic  Electric / Premium Unleaded
# ...             ...        ...          ...                          ...
# 393597        Truck        4WD    Automatic          Electric / Unleaded
# 393598        Truck        4WD    Automatic          Electric / Unleaded
# 393599        Truck        4WD    Automatic          Electric / Unleaded
# 393600        Truck        4WD    Automatic          Electric / Unleaded
# 393602        Truck        4WD    Automatic          Electric / Unleaded
#
#         engine_size engine_block state
# 0               3.5            V    NB
# 1               3.5            V    QC
# 2               3.5            V    BC
# 3               3.5            V    ON
# 4               3.5            V    ON
# ...             ...          ...   ...
# 393597          2.0            I    QC
# 393598          2.0            I    QC
# 393599          2.0            I    QC
# 393600          2.0            I    QC
# 393602          3.0            V    ON
#
# [269552 rows x 13 columns]

# %%
df['make'].unique()
# Out:
# <StringArray>
# [        'Acura',         'Dodge',      'Chrysler',           'RAM',
#           'Ford',     'Chevrolet',         'Buick',      'Cadillac',
#            'GMC',         'Lexus',    'Volkswagen',           'BMW',
#  'Mercedes-Benz',        'Hummer',       'Lincoln',         'Volvo',
#       'INFINITI',        'Toyota',    'Land Rover',          'Audi',
#           'MINI',       'Porsche',      'Maserati',    'Am General',
#           'Jeep',        'Nissan',         'Mazda',        'Jaguar',
#          'Honda',       'Pontiac',    'Oldsmobile',        'Saturn',
#       'Plymouth',       'Mercury',        'Suzuki',           'Kia',
#        'Hyundai',         'Scion',    'Mitsubishi',        'Subaru',
#           'FIAT',       'GENESIS',         'Lotus',          'Saab',
#        'Ferrari',       'McLaren',   'Rolls-Royce',       'Bentley',
#   'Aston Martin',       'Maybach',         'smart',    'Alfa Romeo',
#    'Lamborghini',         'KARMA']
# Length: 54, dtype: string

# %%
df['make'] = df['make'].apply(lambda x : x.lower().replace(' ', '_').replace('-', '_'))

df['make'].unique()
# Out:
# array(['acura', 'dodge', 'chrysler', 'ram', 'ford', 'chevrolet', 'buick',
#        'cadillac', 'gmc', 'lexus', 'volkswagen', 'bmw', 'mercedes_benz',
#        'hummer', 'lincoln', 'volvo', 'infiniti', 'toyota', 'land_rover',
#        'audi', 'mini', 'porsche', 'maserati', 'am_general', 'jeep',
#        'nissan', 'mazda', 'jaguar', 'honda', 'pontiac', 'oldsmobile',
#        'saturn', 'plymouth', 'mercury', 'suzuki', 'kia', 'hyundai',
#        'scion', 'mitsubishi', 'subaru', 'fiat', 'genesis', 'lotus',
#        'saab', 'ferrari', 'mclaren', 'rolls_royce', 'bentley',
#        'aston_martin', 'maybach', 'smart', 'alfa_romeo', 'lamborghini',
#        'karma'], dtype=object)

# %%
df['body_type'] = df['body_type'].apply(lambda x : x.lower().replace(' ', '_').replace('-', '_'))
df['body_type'].unique()
# Out:
# array(['coupe', 'sedan', 'pickup', 'suv', 'convertible', 'hatchback',
#        'targa', 'passenger_van', 'cargo_van', 'chassis_cab', 'minivan',
#        'mini_mpv', 'crossover', 'wagon', 'cutaway', 'micro_car', 'combi',
#        'car_van', 'roadster', 'commercial_wagon'], dtype=object)

# %%
df['vehicle_type'].unique()
# Out:
# <StringArray>
# ['Car', 'Truck']
# Length: 2, dtype: string

# %%
df['drivetrain'].unique()
# Out:
# <StringArray>
# ['4WD', 'FWD', 'RWD']
# Length: 3, dtype: string

# %%
df['transmission'].unique()
# Out:
# <StringArray>
# ['Automatic', 'Manual']
# Length: 2, dtype: string

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# [        'Electric / Premium Unleaded',                                 'E85',
#             'E85 / Unleaded; Unleaded',                      'Unleaded / E85',
#                  'Unleaded / Unleaded', 'E85 / Unleaded; Unleaded / Unleaded',
#           'Premium Unleaded; Unleaded',         'Premium Unleaded / Unleaded',
#         'Compressed Natural Gas / Lpg',   'Compressed Natural Gas / Unleaded',
#                            'Biodiesel',              'E85 / Premium Unleaded',
#                       'Electric / E85',              'Compressed Natural Gas',
#     'Compressed Natural Gas; Unleaded',                 'Unleaded / Electric',
#            'Diesel / Premium Unleaded',                              'Diesel',
#                             'Electric',                            'Unleaded',
#                       'E85 / Unleaded',                    'Premium Unleaded',
#                  'Electric / Unleaded']
# Length: 23, dtype: string

# %%
gasoline = {'gas', 
            'E85 / Unleaded',
       'Unleaded', 'Premium Unleaded',
       'Premium Unleaded; Unleaded', 
       'Unleaded; Unleaded / E85', 'Unleaded / E85',
       'E85 / Unleaded; Unleaded', 'Premium Unleaded / Unleaded',
       'E85 / Premium Unleaded; E85 / Unleaded', 
       'E85', 'E85 / Premium Unleaded', 
       'Compressed Natural Gas; Unleaded',
       'E85 / Unleaded; Unleaded / Unleaded',
       'Diesel / Premium Unleaded', 'E85 / Unleaded; Unleaded / E85',
       'Unleaded / Unleaded', 
       'Compressed Natural Gas / Unleaded', 'Diesel; Unleaded',
       'Diesel; E85 / Unleaded', 'E85 / Unleaded; Premium Unleaded',
       'Premium Unleaded; Premium Unleaded / E85', 'E85; E85 / Unleaded',
       'Unleaded / Premium Unleaded',
       'Premium Unleaded / E85',
       'M85 / Unleaded'
}

biodiesel = {
    'Biodiesel'
}

hybrid = {
       'Electric / Premium Unleaded', 
       'Electric / Unleaded',
       'Unleaded / Electric',
       'Electric / Hydrogen',
       'Electric / Premium Unleaded; Electric / Unleaded',
       'Electric / Premium Unleaded; Premium Unleaded',
       'Electric / E85'
}

other = {
    'Hydrogen', 
    'Premium Unleaded / Natural Gas',
    'Compressed Natural Gas / Lpg', 
    'Compressed Natural Gas', 'Propane',
    'Flex Fuel Vehicle',
}

def preprocess_fuel_type(x):
    if x in gasoline:
        return "gasoline"
    elif x in biodiesel:
        return "biodiesel"
    elif x in hybrid:
        return "hyrid"
    else:
        return "other"
    
df['fuel_type'] = df['fuel_type'].apply(preprocess_fuel_type)

# %%
df['fuel_type'].unique()
# Out:
# array(['hyrid', 'gasoline', 'other', 'biodiesel'], dtype=object)

# %%
df['engine_size'].unique()
# Out:
# array([3.5, 2.7, 3.6, 5.7, 4. , 5. , 5.4, 3. , 1.4, 1.5, 4.6, 6. , 6.6,
#        5.3, 6.2, 6.1, 2.4, 1.6, 2. , 3.3, 1.8, 2.5, 0.6, 2.9, 4.7, 6.5,
#        5.9, 3.2, 6.7, 6.4, 7.3, 2.8, 1.9, 2.2, 2.1, 5.2, 8. , 3.7, 2.3,
#        1. , 3.8, 3.9, 6.8, 4.2, 3.1, 3.4, 4.5, 4.8, 4.3, 8.1, 7.4, 1.7,
#        5.6, 1.3, 1.2, 4.4, 6.3, 8.3, 8.4, 7. , 5.8, 5.5, 2.6, 0.9])

# %%
df['engine_block'].unique()
# Out:
# <StringArray>
# ['V', 'I', 'H']
# Length: 3, dtype: string

# %%
df['state'].unique()
# Out:
# <StringArray>
# ['NB', 'QC', 'BC', 'ON', 'AB', 'MB', 'SK', 'NS', 'PE', 'NL', 'YT', 'NC', 'OH',
#  'SC']
# Length: 14, dtype: string

# %%
unique_make_model = df.groupby(['make', 'model']).size().reset_index(name='count')

non_unique_rows = unique_make_model[unique_make_model['count']>1]

df_filtered = df.merge(non_unique_rows, on=['make', 'model'], how='inner').drop(['count'], axis=1)

# %%
df_filtered.shape
# Out:
# (269493, 13)

# %%
df_filtered.to_csv('../data/used_car_canada_clean.csv', index=False, header=True)

# %% [markdown]
# ## Modeling

# %%
df = pd.read_csv('../data/used_car_canada_clean.csv')
display(df)
# Out:
#            price    miles    year           make          model body_type  \
# 0       179999.0   9966.0  2017.0          acura            NSX     coupe
# 1       179995.0   5988.0  2017.0          acura            NSX     coupe
# 2       168528.0  24242.0  2017.0          acura            NSX     coupe
# 3       220000.0   6637.0  2020.0          acura            NSX     coupe
# 4       220000.0   6637.0  2020.0          acura            NSX     coupe
# ...          ...      ...     ...            ...            ...       ...
# 269488   43900.0  68665.0  2018.0  mercedes_benz      GLC-Class       suv
# 269489   47995.0  22108.0  2019.0  mercedes_benz      GLC-Class       suv
# 269490   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class       suv
# 269491   42995.0  55316.0  2018.0  mercedes_benz      GLC-Class       suv
# 269492  113530.0   7595.0  2020.0        porsche  Cayenne Coupe       suv
#
#        vehicle_type drivetrain transmission fuel_type  engine_size  \
# 0               Car        4WD    Automatic     hyrid          3.5
# 1               Car        4WD    Automatic     hyrid          3.5
# 2               Car        4WD    Automatic     hyrid          3.5
# 3               Car        4WD    Automatic     hyrid          3.5
# 4               Car        4WD    Automatic     hyrid          3.5
# ...             ...        ...          ...       ...          ...
# 269488        Truck        4WD    Automatic     hyrid          2.0
# 269489        Truck        4WD    Automatic     hyrid          2.0
# 269490        Truck        4WD    Automatic     hyrid          2.0
# 269491        Truck        4WD    Automatic     hyrid          2.0
# 269492        Truck        4WD    Automatic     hyrid          3.0
#
#        engine_block state
# 0                 V    NB
# 1                 V    QC
# 2                 V    BC
# 3                 V    ON
# 4                 V    ON
# ...             ...   ...
# 269488            I    QC
# 269489            I    QC
# 269490            I    QC
# 269491            I    QC
# 269492            V    ON
#
# [269493 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=df[['make', 'model']], test_size=0.2, shuffle=True, random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectPercentile, mutual_info_regression

cat_index = [3,4,5,6,7,8,10,11]

cat_features_transformer = Pipeline(
    steps=[
        ("encoder", OrdinalEncoder()),
        ("selector", SelectPercentile(mutual_info_regression, percentile=50))
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", cat_features_transformer, cat_index)
    ]
)

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("regressor", GradientBoostingRegressor(random_state=42))
    ]
)

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OrdinalEncoder()),
#                                                                   ('selector',
#                                                                    SelectPercentile(percentile=50,
#                                                                                     score_func=<function mutual_info_regression at 0x0000028BC7E7C280>))]),
#                                                   [3, 4, 5, 6, 7, 8, 10,
#                                                    11])])),
#                 ('regressor', GradientBoostingRegressor(random_state=42))])

# %%
model.score(X_test, y_test)
# Out:
# 0.4402997195658226
